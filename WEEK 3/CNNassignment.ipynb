# %% [markdown]
# # **CNN assignment**(Do read the note at the end)

# %% [markdown]
# Description: Here we are going to use CNN to classify images of elephants,tigers,cheetah's and crocodiles. Basically multiclass classificiation using CNN.

# %% [markdown]
# **Q.1** Import all required modules

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Your code here
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
from keras.layers import Rescaling
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import BatchNormalization
from keras.layers import Activation
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %% [markdown]
# **Q.2** Load data using image_dataset_from_directory(https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image_dataset_from_directory)

# %%
data=tf.keras.preprocessing.image_dataset_from_directory(
    directory = 'drive/MyDrive/data',
    labels = 'inferred',
    label_mode = 'categorical',
    batch_size=32,
    image_size=(256, 256),
    shuffle = True
)
# Out:
# Found 1658 files belonging to 4 classes.

# %% [markdown]
# *   Since data object is not iterable,we will create a nummpy iterator for data.
# *   Then use batch to iterate through our data

# %%
data_iterator=data.as_numpy_iterator()

# %%
batch=data_iterator.next()

# %% [markdown]
# Run the below code and batch code 2-3 times to visualise the labels given to different animals.

# %%
fig,ax=plt.subplots(ncols=4,figsize=(20,20))
for idx,img in enumerate(batch[0][:4]):
  ax[idx].imshow(img.astype(int))
  ax[idx].title.set_text(str(batch[1][idx]))

# %% [markdown]
# **Q.3** Map the data such that all pixel values lie between 0 and 1 using the **lambda function**

# %%
def rescale(x, y):
    x = tf.cast(x, tf.float32) / 255.0
    return x, y

data=data.map(lambda x, y: rescale((x), y))

# %% [markdown]
# **Q.4** Split the data into train set and test set(and validation set if needed) using **data.take**(https://www.geeksforgeeks.org/tensorflow-js-tf-data-dataset-class-take-method/) and **data.skip**(https://www.geeksforgeeks.org/tensorflow-js-tf-data-dataset-skip-method/)

# %%
data_size = len(data)
train_size = int(0.75*data_size)
val_size = int(0.15*data_size)
test_size = int(0.1*data_size)

train = data.take(train_size)
rem = data.skip(train_size)
val = rem.take(val_size)
test = rem.take(test_size)

# %% [markdown]
# **Creating the model**

# %% [markdown]
# **Q.5** Write code to create CNN model including fully connected layers with softmax as final layer.

# %%
model=Sequential()

model.add(Conv2D(32, (3, 3), strides=1, input_shape=(256, 256, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2, 2), padding ='same'))
model.add(Dropout(0.2))

model.add(Conv2D(64, (3, 3), strides=1, input_shape=(256, 256, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2, 2), padding ='same'))
model.add(Dropout(0.2))

model.add(Conv2D(128, (3,3), padding = 'same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2,2), padding = 'same'))
model.add(Dropout(0.3))

model.add(Conv2D(256, (5,5), padding = 'same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2,2), padding = 'same'))
model.add(Dropout(0.3))

model.add(Conv2D(512, (3,3), padding = 'same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2,2), padding = 'same'))
model.add(Dropout(0.3))

model.add(Flatten())

model.add(Dense(2048))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(4, activation='softmax'))

# %% [markdown]
# **Q.6** Compile your model

# %%
model.compile(
    optimizer = tf.keras.optimizers.RMSprop(0.0001),
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
)

# %% [markdown]
# **Q.7** Fit your model with train set and make sure to keep **less epochs**(10-15) as the dataset size is very large.

# %%
model.fit(train, epochs = 25,
          validation_data=val)
# Out:
# Epoch 1/45
# 39/39 [==============================] - 28s 700ms/step - loss: 0.2633 - accuracy: 0.9295 - val_loss: 5.1723 - val_accuracy: 0.5804
# Epoch 2/45
# 39/39 [==============================] - 27s 673ms/step - loss: 0.3118 - accuracy: 0.9231 - val_loss: 6.2709 - val_accuracy: 0.5625
# Epoch 3/45
# 39/39 [==============================] - 28s 680ms/step - loss: 0.1988 - accuracy: 0.9439 - val_loss: 3.0072 - val_accuracy: 0.6652
# Epoch 4/45
# 39/39 [==============================] - 27s 668ms/step - loss: 0.2100 - accuracy: 0.9423 - val_loss: 3.2140 - val_accuracy: 0.6562
# Epoch 5/45
# 39/39 [==============================] - 27s 662ms/step - loss: 0.1941 - accuracy: 0.9399 - val_loss: 4.1035 - val_accuracy: 0.5938
# Epoch 6/45
# 39/39 [==============================] - 27s 671ms/step - loss: 0.1679 - accuracy: 0.9535 - val_loss: 5.8789 - val_accuracy: 0.5759
# Epoch 7/45
# 39/39 [==============================] - 27s 662ms/step - loss: 0.1790 - accuracy: 0.9455 - val_loss: 3.8800 - val_accuracy: 0.6830
# Epoch 8/45
# 39/39 [==============================] - 28s 687ms/step - loss: 0.1635 - accuracy: 0.9511 - val_loss: 2.5373 - val_accuracy: 0.7411
# Epoch 9/45
# 39/39 [==============================] - 26s 650ms/step - loss: 0.1462 - accuracy: 0.9543 - val_loss: 1.4013 - val_accuracy: 0.8482
# Epoch 10/45
# 39/39 [==============================] - 26s 645ms/step - loss: 0.1201 - accuracy: 0.9671 - val_loss: 1.8054 - val_accuracy: 0.7902
# Epoch 11/45
# 39/39 [==============================] - 26s 643ms/step - loss: 0.1609 - accuracy: 0.9623 - val_loss: 2.3100 - val_accuracy: 0.7232
# Epoch 12/45
# 39/39 [==============================] - 27s 660ms/step - loss: 0.0933 - accuracy: 0.9752 - val_loss: 1.7204 - val_accuracy: 0.7634
# Epoch 13/45
# 39/39 [==============================] - 34s 857ms/step - loss: 0.1060 - accuracy: 0.9744 - val_loss: 2.2845 - val_accuracy: 0.7232
# Epoch 14/45
# 39/39 [==============================] - 27s 656ms/step - loss: 0.1217 - accuracy: 0.9671 - val_loss: 1.8436 - val_accuracy: 0.7455
# Epoch 15/45
# 39/39 [==============================] - 28s 680ms/step - loss: 0.1125 - accuracy: 0.9752 - val_loss: 2.0008 - val_accuracy: 0.7946
# Epoch 16/45
# 39/39 [==============================] - 26s 650ms/step - loss: 0.0923 - accuracy: 0.9768 - val_loss: 1.0751 - val_accuracy: 0.8839
# Epoch 17/45
# 39/39 [==============================] - 26s 640ms/step - loss: 0.1408 - accuracy: 0.9696 - val_loss: 2.1692 - val_accuracy: 0.7589
# Epoch 18/45
# 39/39 [==============================] - 26s 647ms/step - loss: 0.1108 - accuracy: 0.9744 - val_loss: 2.2537 - val_accuracy: 0.7768
# Epoch 19/45
# 39/39 [==============================] - 28s 681ms/step - loss: 0.0932 - accuracy: 0.9736 - val_loss: 2.5448 - val_accuracy: 0.7455
# Epoch 20/45
# 39/39 [==============================] - 26s 648ms/step - loss: 0.0714 - accuracy: 0.9800 - val_loss: 1.9590 - val_accuracy: 0.7991
# Epoch 21/45
# 39/39 [==============================] - 26s 638ms/step - loss: 0.0720 - accuracy: 0.9808 - val_loss: 2.4679 - val_accuracy: 0.7411
# Epoch 22/45
# 39/39 [==============================] - 28s 681ms/step - loss: 0.0636 - accuracy: 0.9832 - val_loss: 1.6408 - val_accuracy: 0.8036
# Epoch 23/45
# 39/39 [==============================] - 26s 644ms/step - loss: 0.0713 - accuracy: 0.9792 - val_loss: 2.2888 - val_accuracy: 0.7679
# Epoch 24/45
# 39/39 [==============================] - 26s 646ms/step - loss: 0.0486 - accuracy: 0.9872 - val_loss: 2.0859 - val_accuracy: 0.7589
# Epoch 25/45
# 39/39 [==============================] - 26s 629ms/step - loss: 0.0825 - accuracy: 0.9840 - val_loss: 2.5408 - val_accuracy: 0.7455
# Epoch 26/45
# 39/39 [==============================] - 35s 857ms/step - loss: 0.0639 - accuracy: 0.9832 - val_loss: 1.0824 - val_accuracy: 0.8393
# Epoch 27/45
# 39/39 [==============================] - 26s 639ms/step - loss: 0.0573 - accuracy: 0.9808 - val_loss: 1.3693 - val_accuracy: 0.8304
# Epoch 28/45
# 39/39 [==============================] - 26s 633ms/step - loss: 0.0705 - accuracy: 0.9864 - val_loss: 1.9642 - val_accuracy: 0.7991
# Epoch 29/45
# 39/39 [==============================] - 28s 685ms/step - loss: 0.0652 - accuracy: 0.9872 - val_loss: 2.7036 - val_accuracy: 0.7500
# Epoch 30/45
# 39/39 [==============================] - 26s 645ms/step - loss: 0.0577 - accuracy: 0.9864 - val_loss: 3.4578 - val_accuracy: 0.7098
# Epoch 31/45
# 39/39 [==============================] - 26s 646ms/step - loss: 0.0543 - accuracy: 0.9864 - val_loss: 1.1848 - val_accuracy: 0.8750
# Epoch 32/45
# 39/39 [==============================] - 27s 653ms/step - loss: 0.0558 - accuracy: 0.9856 - val_loss: 0.5813 - val_accuracy: 0.9241
# Epoch 33/45
# 39/39 [==============================] - 34s 858ms/step - loss: 0.0532 - accuracy: 0.9864 - val_loss: 0.9055 - val_accuracy: 0.8884
# Epoch 34/45
# 39/39 [==============================] - 27s 657ms/step - loss: 0.0456 - accuracy: 0.9880 - val_loss: 2.0556 - val_accuracy: 0.8214
# Epoch 35/45
# 39/39 [==============================] - 26s 646ms/step - loss: 0.0316 - accuracy: 0.9920 - val_loss: 1.4390 - val_accuracy: 0.8393
# Epoch 36/45
# 39/39 [==============================] - 26s 649ms/step - loss: 0.0341 - accuracy: 0.9896 - val_loss: 1.6680 - val_accuracy: 0.8661
# Epoch 37/45
# 39/39 [==============================] - 27s 675ms/step - loss: 0.0401 - accuracy: 0.9888 - val_loss: 1.3849 - val_accuracy: 0.8616
# Epoch 38/45
# 39/39 [==============================] - 34s 854ms/step - loss: 0.0394 - accuracy: 0.9896 - val_loss: 1.5939 - val_accuracy: 0.8170
# Epoch 39/45
# 39/39 [==============================] - 26s 638ms/step - loss: 0.0308 - accuracy: 0.9944 - val_loss: 1.3233 - val_accuracy: 0.8661
# Epoch 40/45
# 39/39 [==============================] - 26s 638ms/step - loss: 0.0378 - accuracy: 0.9888 - val_loss: 3.1609 - val_accuracy: 0.7143
# Epoch 41/45
# 39/39 [==============================] - 35s 883ms/step - loss: 0.0550 - accuracy: 0.9864 - val_loss: 1.7856 - val_accuracy: 0.8348
# Epoch 42/45
# 39/39 [==============================] - 26s 644ms/step - loss: 0.0433 - accuracy: 0.9888 - val_loss: 1.1250 - val_accuracy: 0.9018
# Epoch 43/45
# 39/39 [==============================] - 27s 678ms/step - loss: 0.0463 - accuracy: 0.9880 - val_loss: 1.8605 - val_accuracy: 0.8393
# Epoch 44/45
# 39/39 [==============================] - 26s 638ms/step - loss: 0.0620 - accuracy: 0.9856 - val_loss: 1.2029 - val_accuracy: 0.8661
# Epoch 45/45
# 39/39 [==============================] - 26s 636ms/step - loss: 0.0405 - accuracy: 0.9896 - val_loss: 1.4897 - val_accuracy: 0.8705

# %% [markdown]
# **Q.8** Test your code with test set

# %%
loss,accuracy=model.evaluate(test)
# Out:
# 5/5 [==============================] - 20s 206ms/step - loss: 1.5046 - accuracy: 0.8562

# %%
# Do not change this code
if accuracy>=0.85:
  print(f"Congratulations, CNN assignment complete!! Your accuracy is {accuracy}")
else:
  print(f"Try again, not enough accuracy! Your accuracy is {accuracy}" )
# Out:
# Congratulations, CNN assignment complete!! Your accuracy is 0.856249988079071

# %% [markdown]
# **Note: 1. Many of you will get very high train accuracy but low test accuracy. This is called overfitting, this can be solved by increasing the train set size. If your getting low accuracy for both train and test, modify your layers in the model.**
#
# **2.Do use T4GPU.Ideally your first epoch will take quite sometime and rest of the epochs will be faster but if all your epochs are taking a lot of time, try starting a new gpu session(open a new gmail account and open colab on that) because your free gpu might have exhausted itself.**
#
# **3.Other than that everything should be fine, happy learning!!**
